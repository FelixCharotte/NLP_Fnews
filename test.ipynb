# %%
from datasets import load_dataset
dataset = load_dataset("Achillektf/NLP_News")

# %%
import pandas as pd

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'output', 'Instruction'],
#         num_rows: 460
#     })
# })

# %%
df = pd.DataFrame(dataset["train"])

# %%
df
# Out:
#                                                  input     output  \
# 0    Bitcoin dips as the U.S. banking crisis engulf...  -0.647692
# 1    Bitcoin (BTC/USD) sought to add to recent gain...  -0.647692
# 2    The current Bitcoin cycle is now 75% on the wa...  -0.647692
# 3    BTC/USD Stops Elected Below 28164:  Sally Ho’s...  -0.647692
# 4    Trusted since 2012, BitKan cryptocurrency brok...  -0.647692
# ..                                                 ...        ...
# 455  Bitcoin’s price gain was the biggest in six mo...  10.560892
# 456  Timing the market bottom is impossible, but se...  10.560892
# 457  Authored by Marty Bent via BitcoinMagazine.com...  10.560892
# 458  Bitcoin surges on U.S. dollar weakness with BT...  10.560892
# 459  Bitcoin brings financial education to the fore...   2.672771
#
#                                            Instruction
# 0    Predict price variation in percentage of the B...
# 1    Predict price variation in percentage of the B...
# ...

# %%
import pandas as pd

# Création d'un DataFrame exemple
# Séparation en quartiles avec des étiquettes personnalisées
df['output'] = pd.qcut(df['output'], q=4, labels=['Extreme Bearish', 'Bearish', 'Bullish', 'Extrem Bullish'])

# %%
df
# Out:
#                                                  input          output  \
# 0    Bitcoin dips as the U.S. banking crisis engulf...         Bearish
# 1    Bitcoin (BTC/USD) sought to add to recent gain...         Bearish
# 2    The current Bitcoin cycle is now 75% on the wa...         Bearish
# 3    BTC/USD Stops Elected Below 28164:  Sally Ho’s...         Bearish
# 4    Trusted since 2012, BitKan cryptocurrency brok...         Bearish
# ..                                                 ...             ...
# 455  Bitcoin’s price gain was the biggest in six mo...  Extrem Bullish
# 456  Timing the market bottom is impossible, but se...  Extrem Bullish
# 457  Authored by Marty Bent via BitcoinMagazine.com...  Extrem Bullish
# 458  Bitcoin surges on U.S. dollar weakness with BT...  Extrem Bullish
# 459  Bitcoin brings financial education to the fore...  Extrem Bullish
#
#                                            Instruction
# 0    Predict price variation in percentage of the B...
# ...

# %%
df.to_csv("HG_NLP_Cat",index=False)
